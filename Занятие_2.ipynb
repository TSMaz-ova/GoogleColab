# %% [markdown]
# <a href="https://colab.research.google.com/github/TSMaz-ova/GoogleColab/blob/main/%D0%97%D0%B0%D0%BD%D1%8F%D1%82%D0%B8%D0%B5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Задача №63.
# 1. Изобразите отношение households к population с
# помощью точечного графика
# 2. Визуализировать longitude по отношения к
# median_house_value, используя линейный график
# 3. Представить гистограмму по housing_median_age
# 4. Изобразить гистограмму по median_house_value с
# оттенком housing_median_age
#
# * [Большая шпаргалка по Seaborn](https://mipt-stats.gitlab.io/courses/python/09_seaborn.html)
# * [Документация по Seaborn](https://seaborn.pydata.org/generated/seaborn.set_theme.html#seaborn.set_theme)
# * [Про виды графиков](https://www.geeksforgeeks.org/seaborn-style-and-color/?ref=lbp)

# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
sns.set(style = 'dark', context = 'notebook', palette = 'gray')
sns.scatterplot(data = df, x = 'households', y = 'population')
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
sns.set_style('dark')
sns.relplot(x = 'longitude', y = 'median_house_value', kind = 'line', data = df)

# %%
sns.histplot(data = df, x = 'housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
sns.displot(x = 'median_house_value',data=df,  hue = 'housing_median_age')

# %% [markdown]
# ## Задача №65. Написать EDA для датасета про пингвинов
# Необходимо:
# * Использовать 2-3 точечных графика
# * Применить доп измерение в точечных графиках, используя
# аргументы hue, size, stile
# * Использовать PairGrid с типом графика на ваш выбор
# * Использовать 2-3 гистограммы
#
# *Чтобы подключить датасет с
# пингвинами, воспользуйтесь данным
# скриптом:*
#
# ```
# penguins = sns.load_dataset("penguins")
# penguins.head()
# ```

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
sns.scatterplot(x='bill_length_mm', y = 'bill_depth_mm', data=penguins, palette = 'rainbow', hue = 'species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(x='body_mass_g', y = 'bill_length_mm', data=penguins, palette = 'rainbow', hue = 'species', size ='sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='bill_length_mm'>

# %%
sns.scatterplot(x='flipper_length_mm', y = 'bill_length_mm', data=penguins, palette = 'rainbow', hue = 'sex', size ='species')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
g = sns.PairGrid(penguins, diag_sharey=False, hue = 'species')
g.map_lower(sns.kdeplot, cmap='Blues_d')
# g.map_upper(plt.scatter, alpha=0.5)
# g.map_diag(sns.kdeplot, lw=3);
g.map(sns.scatterplot)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
# ...

# %%
sns.histplot(x = 'species', data=penguins, palette = 'rainbow')
# Out:
# <ipython-input-75-f786ce0156ed>:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x = 'species', data=penguins, palette = 'rainbow')
# <Axes: xlabel='species', ylabel='Count'>

# %%
sns.histplot(x='island', data = penguins, palette = 'inferno', hue = 'species')
# Out:
# <Axes: xlabel='island', ylabel='Count'>

# %%
sns.histplot(x='body_mass_g', data = penguins, palette = 'rainbow', hue = 'species')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# ## Задача №67.
# 1. Создать новый столбец в таблице с
# пингвинами, который будет отвечать за
# показатель длины клюва пингвина.
# high - длинный(от 42)
# middle - средний(от 35 до 42)
# low - маленький(до 35)
#
# *Чтобы подключить датасет с
# пингвинами, воспользуйтесь данным
# скриптом:*
#
# ```
# penguins = sns.load_dataset("penguins")
# penguins.head()
# ```

# %%
penguins.loc[penguins['bill_length_mm']>=42, 'indicator'] = 'high'
penguins.loc[(penguins['bill_length_mm']<42) & (penguins['bill_length_mm'] > 35), 'indicator'] = 'middle'
penguins.loc[penguins['bill_length_mm']<=35, 'indicator'] = 'low'

# %%
from inspect import stack
sns.histplot(data = penguins, x = 'indicator', hue = 'sex', multiple='stack')
# Out:
# <Axes: xlabel='indicator', ylabel='Count'>

# %%
sns.histplot

# %% [markdown]
# ## Задача №69.
# 1. Изобразить гистограмму по flipper_length_mm
# с оттенком height_group.
# 2. Сделать анализ

# %%
sns.histplot(data=penguins, x =  'flipper_length_mm', hue = 'indicator')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# Полученный результат показывает взимосвязь длины крыла и среднего размера клюва. Т.е. чем больше крыло, тем больше клюв. Т.е. клювы превышающие средние размеры в большей степени имеют крупные особи. Средние и маленькие клювы соответствуют особям средних и маленьких размеров.

# %% [markdown]
# ## Домашняя работа
# В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего
# из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без
# get_dummies?
#
# ```
# import random
# lst = ['robot'] * 10
# lst += ['human'] * 10
# random.shuffle(lst)
# data = pd.DataFrame({'whoAmI':lst})
# data.head()
# ```
# [Статья про one hot вид](https://colab.research.google.com/drive/1qKamnDiRmpRZkpiqWPkunBdAhmzhMcGz?usp=sharing)

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  robot
# 1  robot
# 2  human
# 3  robot
# 4  robot

# %%
pd.get_dummies(data['whoAmI'])
# Out:
#     human  robot
# 0   False   True
# 1   False   True
# 2    True  False
# 3   False   True
# 4   False   True
# 5   False   True
# 6   False   True
# 7    True  False
# 8    True  False
# 9    True  False
# 10   True  False
# 11   True  False
# 12  False   True
# 13  False   True
# 14   True  False
# 15  False   True
# 16   True  False
# 17  False   True
# 18   True  False
# 19   True  False

# %%
data.loc[data['whoAmI']=='human', 'human'] = 'True'
data.loc[data['whoAmI']=='robot', 'human'] = 'False'
data.loc[data['whoAmI']=='robot', 'robot'] = 'True'
data.loc[data['whoAmI']=='human', 'robot'] = 'False'
print(data)
# Out:
#    whoAmI  human  robot
# 0   robot  False   True
# 1   robot  False   True
# 2   human   True  False
# 3   robot  False   True
# 4   robot  False   True
# 5   robot  False   True
# 6   robot  False   True
# 7   human   True  False
# 8   human   True  False
# 9   human   True  False
# 10  human   True  False
# 11  human   True  False
# 12  robot  False   True
# 13  robot  False   True
# 14  human   True  False
# 15  robot  False   True
# 16  human   True  False
# 17  robot  False   True
# 18  human   True  False
# 19  human   True  False
