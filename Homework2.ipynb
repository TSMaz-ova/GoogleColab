# %% [markdown]
# <a href="https://colab.research.google.com/github/TSMaz-ova/GoogleColab/blob/main/Homework2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Домашняя работа
# В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего
# из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без
# get_dummies?
#
# ```
# import random
# lst = ['robot'] * 10
# lst += ['human'] * 10
# random.shuffle(lst)
# data = pd.DataFrame({'whoAmI':lst})
# data.head()
# ```
# [Статья про one hot вид](https://colab.research.google.com/drive/1qKamnDiRmpRZkpiqWPkunBdAhmzhMcGz?usp=sharing)

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  robot
# 1  robot
# 2  human
# 3  robot
# 4  robot

# %%
pd.get_dummies(data['whoAmI'])
# Out:
#     human  robot
# 0   False   True
# 1   False   True
# 2    True  False
# 3   False   True
# 4   False   True
# 5   False   True
# 6   False   True
# 7    True  False
# 8    True  False
# 9    True  False
# 10   True  False
# 11   True  False
# 12  False   True
# 13  False   True
# 14   True  False
# 15  False   True
# 16   True  False
# 17  False   True
# 18   True  False
# 19   True  False

# %%
data.loc[data['whoAmI']=='human', 'human'] = 'True'
data.loc[data['whoAmI']=='robot', 'human'] = 'False'
data.loc[data['whoAmI']=='robot', 'robot'] = 'True'
data.loc[data['whoAmI']=='human', 'robot'] = 'False'
print(data)
# Out:
#    whoAmI  human  robot
# 0   robot  False   True
# 1   robot  False   True
# 2   human   True  False
# 3   robot  False   True
# 4   robot  False   True
# 5   robot  False   True
# 6   robot  False   True
# 7   human   True  False
# 8   human   True  False
# 9   human   True  False
# 10  human   True  False
# 11  human   True  False
# 12  robot  False   True
# 13  robot  False   True
# 14  human   True  False
# 15  robot  False   True
# 16  human   True  False
# 17  robot  False   True
# 18  human   True  False
# 19  human   True  False
